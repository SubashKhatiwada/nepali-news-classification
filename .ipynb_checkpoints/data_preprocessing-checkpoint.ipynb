# %%
import os
import pandas as pd

# Specify the root directory where your dataset is located
dataset_root_dir = '0_raw_dataset'

# Initialize empty lists to store file names, labels, and contents
file_names = []
labels = []
contents = []

# Traverse through each folder
for folder in os.listdir(dataset_root_dir):
    folder_path = os.path.join(dataset_root_dir, folder)
    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            if file.endswith('.txt'):
                file_path = os.path.join(folder_path, file)
                with open(file_path, 'r', encoding='utf-8', errors='ignore') as txt_file:
                    file_contents = txt_file.read().strip()
                file_names.append(file)
                labels.append(folder)  # Store the folder name directly as the label
                contents.append(file_contents)

# Create a DataFrame from the lists with labels as folder names directly
df = pd.DataFrame({
    'file_id': file_names,
    'content': contents,
    'label': labels
})
label_counts = df['label'].value_counts()
print(label_counts)
# Sort the DataFrame by the 'label' column
df = df.sort_values(by='label', ascending=True)

# Display the DataFrame with labels as folder names
print(df)

# Specify the path where you want to save the CSV file
combined_data_path = '1_combined_dataset/combined.csv'
df.to_csv(combined_data_path, index=False)

print(f"Data saved to {combined_data_path}")
# Out:
# label
# Entertainment         580
# Economy               431
# Sports                381
# Opinion               319
# National News         227
# Bank                  184
# Blog                  119
# Tourism               110
# World                 105
# Employment             76
# Technology             57
# Education              46
# Interview              40
# Literature             16
# Business Interview     13
# Auto                    5
# Name: count, dtype: int64
#              file_id                                            content  label
# 614   1482772260.txt  ﻿\n११ पुस, काठमाडौं । एम भी दुगड ग्रुपको विवेक...   Auto
# 618   1482076440.txt  ﻿\n३ पुस, काठमाडौं । आइएमएस मोटर्सले काठमाडौंक...   Auto
# 615   1483033980.txt  ﻿\n१४ पुस, काठमाडौं । नयाँ जमानाको स्पोर्टी ह्...   Auto
# 616   1482687900.txt  ﻿\n१० पुस, काठमाडाैं । डाट्सन गाडीको आधिकारिक ...   Auto
# 617   1483039080.txt  ﻿\n१४ पुस, काठमाडौं । लक्ष्मी इन्टरकन्टिनेन्टल...   Auto
# ...              ...                                                ...    ...
# 1777  1445157614.txt  ﻿भारतको रक्सौल नाकामा पछिल्लो २४ दिनदेखि रोकिए...  World
# 1776  1437063153.txt  ﻿जासुसी गर्न भारतले पठाएको ड्रोन पाकिस्तानले ख...  World
# 1775  1443986594.txt  ﻿भारतले वीरगञ्ज नाका बाहेक अरु नाकाहरु खोल्ने ...  World
# 1773  1452367202.txt  ﻿दिल्ली, २५ पुस । नयां दिल्लीमा उपचार गराएर स्...  World
# 1788  1441459665.txt  ﻿टर्कीको समुन्द्री किनारमा फेला परेको एक तीन व...  World
#
# [2709 rows x 3 columns]
# Data saved to 1_combined_dataset/combined.csv

# %%
import pandas as pd
import json
from sklearn.preprocessing import LabelEncoder

# Load the data
data = pd.read_csv("1_combined_dataset/combined.csv")

# Encode labels and save mapping
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data['label'])
label_mapping = {label: int(code) for label, code in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))}

# Save label mapping to JSON
with open("1_combined_dataset/label_mapping.json", "w") as file:
    json.dump(label_mapping, file)

# Define your preprocess function if not already defined
def preprocess(text):
    return text.lower()  # Example: convert to lowercase

# Preprocess the 'content' column
data['content'] = data['content'].apply(preprocess)

# Save the encoded and preprocessed data back to CSV
data.to_csv("1_combined_dataset/encoded_combined.csv", index=False)

print(data)
# Out:
#              file_id                                            content  label
# 0     1482772260.txt  ﻿\n११ पुस, काठमाडौं । एम भी दुगड ग्रुपको विवेक...      0
# 1     1482076440.txt  ﻿\n३ पुस, काठमाडौं । आइएमएस मोटर्सले काठमाडौंक...      0
# 2     1483033980.txt  ﻿\n१४ पुस, काठमाडौं । नयाँ जमानाको स्पोर्टी ह्...      0
# 3     1482687900.txt  ﻿\n१० पुस, काठमाडाैं । डाट्सन गाडीको आधिकारिक ...      0
# 4     1483039080.txt  ﻿\n१४ पुस, काठमाडौं । लक्ष्मी इन्टरकन्टिनेन्टल...      0
# ...              ...                                                ...    ...
# 2704  1445157614.txt  ﻿भारतको रक्सौल नाकामा पछिल्लो २४ दिनदेखि रोकिए...     15
# 2705  1437063153.txt  ﻿जासुसी गर्न भारतले पठाएको ड्रोन पाकिस्तानले ख...     15
# 2706  1443986594.txt  ﻿भारतले वीरगञ्ज नाका बाहेक अरु नाकाहरु खोल्ने ...     15
# 2707  1452367202.txt  ﻿दिल्ली, २५ पुस । नयां दिल्लीमा उपचार गराएर स्...     15
# 2708  1441459665.txt  ﻿टर्कीको समुन्द्री किनारमा फेला परेको एक तीन व...     15
#
# [2709 rows x 3 columns]

# %%
nepali_stopwords = []

# Load stopwords from file
with open("0_nepali_corpus/nepali_stopwords.txt", "r", encoding='utf-8', errors='ignore') as file:
    nepali_stopwords = [line.strip() for line in file]
    
stopwords = nepali_stopwords
# print(stopwords)

# Define Nepali tokenizer function
def preprocess(text):
    text = re.sub(r'[a-zA-Z0-9!@#$%^&*()_+\-=\[\]{};\'‘\\:"|<,./<>?~`।१२३४५६७८९०–÷]', '', text)
    text = re.sub(r'।', '', text)
    text = re.sub(r'\ufeff', '', text)
    text = re.sub(r'\\u200d', '', text)
    text = text.replace('\n', ' ')
    return text

# Read and preprocess the dataset
data = pd.read_csv("1_combined_dataset/encoded_combined.csv")
for i in range(len(data)):
    data.at[i, 'content'] = preprocess(data.at[i, 'content'])
print(data)



# Save preprocessed data
data.to_csv("2_preprocessed_dataset/preproccessed_data.csv", index=False)
# Out:
#              file_id                                            content  label
# 0     1482772260.txt    पुस काठमाडौं  एम भी दुगड ग्रुपको विवेक अटोमो...      0
# 1     1482076440.txt    पुस काठमाडौं  आइएमएस मोटर्सले काठमाडौंको नक्...      0
# 2     1483033980.txt    पुस काठमाडौं  नयाँ जमानाको स्पोर्टी ह्याचब्य...      0
# 3     1482687900.txt    पुस काठमाडाैं  डाट्सन गाडीको आधिकारिक विक्रे...      0
# 4     1483039080.txt    पुस काठमाडौं  लक्ष्मी इन्टरकन्टिनेन्टलले आफ्...      0
# ...              ...                                                ...    ...
# 2704  1445157614.txt  भारतको रक्सौल नाकामा पछिल्लो  दिनदेखि रोकिएका ...     15
# 2705  1437063153.txt  जासुसी गर्न भारतले पठाएको ड्रोन पाकिस्तानले खस...     15
# 2706  1443986594.txt  भारतले वीरगञ्ज नाका बाहेक अरु नाकाहरु खोल्ने भ...     15
# 2707  1452367202.txt  दिल्ली  पुस  नयां दिल्लीमा उपचार गराएर स्वास्थ...     15
# 2708  1441459665.txt  टर्कीको समुन्द्री किनारमा फेला परेको एक तीन वर...     15
#
# [2709 rows x 3 columns]

# %%
# Read preprocessed data and drop the file_id column
data = pd.read_csv("2_preprocessed_dataset/preproccessed_data.csv")
data = data.drop(columns=['file_id'])  # Dropping the first column (file_id)
# print(data)

# Convert DataFrame to Hugging Face Dataset
dataset = Dataset.from_pandas(data)
# print("Dataset:")
# print(dataset, "\n")

# Split dataset into train and test sets
# Split data into train and test (60% train, 40% test)
split_dataset = dataset.train_test_split(test_size=0.4)
train_dataset = split_dataset['train']
test_dataset = split_dataset['test']

# Split test data further into validation data and test data (60% validation, 40% test)
test_split = test_dataset.train_test_split(test_size=0.4)  # 60% of the test set will be validation
validation_dataset = test_split['train']
test_dataset = test_split['test']

# print("Trainning Dataset:\n",train_dataset)
# print("Testing Dataset:\n",test_dataset)
# print("Validation Dataset:\n",validation_dataset)


# Save train, validation, and test datasets
# Convert Hugging Face Datasets to Pandas DataFrames before saving
train_df = train_dataset.to_pandas()
validation_df = validation_dataset.to_pandas()
test_df = test_dataset.to_pandas()

# Save as CSV files
train_df.to_csv("3_split_data/train.csv", index=False) 
validation_df.to_csv("3_split_data/validation.csv", index=False) 
test_df.to_csv("3_split_data/test.csv", index=False)

# Print summaries of the datasets
print("Train Dataset:\n", train_df.head())
print("Validation Dataset:\n", validation_df.head())
print("Test Dataset:\n", test_df.head())
# Out:
# Train Dataset:
#                                               content  label
# 0  एजेन्सी  चीन र  रूसले मिलेर संसारकै सबैभन्दा श...     15
# 1   मंसिर काठमाडौं  उद्योगमन्त्री नविन्द्रराज जोश...      4
# 2  एनसेलले थप विकल्पसहित नयाँ डाटा योजना ल्याएको ...     13
# 3    असोज काठमाडौं  वैदेशिक रोजगारीमा जाने नेपाली...      4
# 4  नेपाली कांग्रेस माओवादी केन्द्र लोकतान्त्रिक फ...     12
# Validation Dataset:
#                                               content  label
# 0  फिल्मको प्रमोशनमा कलाकार नहिंड्ने रोग नयाँ हैन...      7
# 1    पुस काठमाडौं  बेरोजगारीले एउटा जल्दोबल्दो यु...      6
# 2   असार काठमाडौं  दुग्ध विकास संस्थान डिडिसीले ब...      4
# 3   खिम घले पछिल्लो समयमा नेपाली राजनीतिमा डा सीक...     11
# 4    पुस काठमाडौं  बार्सिलोनाका ब्राजिलियन स्ट्रा...     12
# Test Dataset:
#                                               content  label
# 0  राजविराज  वैशाख  वैदेशिक रोजगारीमा साउदी अरब प...     10
# 1  अमेरिकाको फ्लोरिडा राज्यका पूर्व गभर्नर जेब बु...     15
# 2  सत्तारुढ दल कांग्रेसले संविधान संशोधनको विषयमा...     12
# 3  भाद्र शुक्ल पञ्चमीका दिनमा मनाइने ऋषिपञ्चमी पर...      7
# 4   ब्रिटिशभारतीय गोर्खा पल्टन जस्तै नेपालमा पनि ...      2

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# Load the label mapping from JSON
label_mapping_path = '1_combined_dataset/label_mapping.json'
with open(label_mapping_path, 'r') as json_file:
    label_mapping = json.load(json_file)

# Reverse the label mapping to get category names by their encoded values
reverse_label_mapping = {v: k for k, v in label_mapping.items()}

# Load the dataset and drop the 'file_id' column
df = pd.read_csv("1_combined_dataset/encoded_combined.csv")
df = df.drop(columns=['file_id'])  # Dropping the 'file_id' column

# Map the numerical labels back to category names
df['label'] = df['label'].map(reverse_label_mapping)

# Count the number of occurrences of each label in the original order
label_counts = df['label'].value_counts()
label_counts = label_counts.reindex(reverse_label_mapping.values())  # Keep original order

# Plot the distribution of labels
plt.figure(figsize=(10, 6))
sns.barplot(x=label_counts.index, y=label_counts.values)
plt.title('Number of news per category')
plt.xlabel('Category')
plt.ylabel('Number of Data Points')
plt.xticks(rotation=45)
plt.show()
