# %%
# !scrapy crawl onlinekhabar
# Out:
# 2025-04-11 11:18:32 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: onlinekhabar_scraper)
# 2025-04-11 11:18:32 [scrapy.utils.log] INFO: Versions: lxml 5.2.1.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 10:07:17) [Clang 14.0.6 ], pyOpenSSL 24.0.0 (OpenSSL 3.0.15 3 Sep 2024), cryptography 42.0.5, Platform macOS-15.3.2-arm64-arm-64bit
# 2025-04-11 11:18:32 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-04-11 11:18:32 [asyncio] DEBUG: Using selector: KqueueSelector
# 2025-04-11 11:18:32 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-04-11 11:18:32 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-04-11 11:18:32 [scrapy.extensions.telnet] INFO: Telnet Password: 983fddae4ee56a73
# 2025-04-11 11:18:32 [scrapy.middleware] INFO: Enabled extensions:
# ...
